# %% [markdown]
# <a href="https://colab.research.google.com/github/RPS1043/Hotel-Booking-Analysis/blob/main/Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - **HOTEL BOOKING ANALYSIS**

# %% [markdown]
# ##### **Project Type**    - EDA - Exploratory Data Analysis
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The dataset contains Hotel Booking between city hotel and resort hotel.
#
# *we will divide our work flow into the following 3 steps.
#
# 1.   Data Collection and Understanding
# 2.   Data Cleaning and Manipulation
# 3.   Exploratory Data Analysis(EDA)
#
# EDA will be divided into following 3 analysis.
# 1.   Univariate analysis: Univariate analysis is the simplest of the three analyses where the data, you are analyzing is only one variable.
# 2.   Bivariate analysis: Bivariate analysis is where you are comparing two variables to study their relationships.
# 3.   Multivariate analysis: Multivariate analysis is similar to Bivariate analysis but you are comparing more than two variables.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/RPS1043/Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In the project hotel booking analysis, the problem's occurrences are the booking cancellation, double-booked room or mishandled reservation is a tough but sometimes unavoidable part of the job, and it's still a nightmare of any hotel manager, are the current problems hotels are facing.
#
# So,implementing some changes in hotel system like giving your guests accurate and helpful information will go a long way to smoothing out their booking process, developing an eye-catching website, user-friendly hotel website and by using a commission-free booking engine are ideas over the above problem solving, but most importantly offering loyalty to customer counts more.
#
# The main objective behind this project is to explore and analyze data to discover important factors that govern the bookings and give insights to hotel management, which can perform various campaigns to boost the business and performance.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Objective is to summerize the data to graphical representation often using statistical and other data visualization method to get insight information for growth of business.

# %% [markdown]
# # ***Let's Begin !***
#
# ![hotel booking image final.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing all four Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Set maximum columns to be display in dataframe as 40
pd.set_option("display.max_columns", 40)                                    
#pd.reset_option("all") ------>used to reset all display
plt.style.use('seaborn')

# Setting fontsizes,fontweight,label weight for lebels,titles.
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titlesize"] = 25
plt.rcParams["axes.titleweight"] = 'bold'
plt.rcParams['xtick.labelsize']=15
plt.rcParams['ytick.labelsize']=15
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["legend.fontsize"] = 15
plt.rcParams["legend.title_fontsize"] = 10

# %%
pip install --upgrade "kaleido==0.1.*"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 MB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: kaleido
#     Found existing installation: kaleido 0.2.1
#     Uninstalling kaleido-0.2.1:
#       Successfully uninstalled kaleido-0.2.1
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting drive to colab note
from google.colab import drive                                                               
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Path link of the file (Dataset)
path = '/content/drive/MyDrive/ALMABETTER DATA SCIENCE/Capston project/HOTEL BOOKINGS'   
#Reads and loads dataset using pandas library and assigned to new variable name dataframe as df   
df = pd.read_csv(path + "/Hotel Bookings.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# To counts total number of dataset Rows & Columns. 
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
#Info method allows us to learn about shape of abject type of our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Info method displays summary of statistics for numerical colimns in our data.
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicated_rows=df.duplicated().value_counts()                                               # True index values are duplicated rows
duplicated_rows
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
#Set plot size
plt.figure(figsize = (12,6))
# plotting count plot using seaborn
fig =sns.countplot(x=df.duplicated())
#set labels
plt.title("duplicated values:True is number of duplicated rows")
plt.xticks(rotation = 0)
plt.yticks(rotation =30)
plt.legend(duplicated_rows.values)
plt.savefig('save_as_a_png.png')

# %% [markdown]
# #####we have 31994 duplicated rows of total 119390 rows of our hotel booking dataset.So, we need to drop all the 31994 rows fom dataset.

# %% [markdown]
# #####After droping duplicate values the rows was reduced to 87396 of 119390 by differenciating with 31994 duplicated rows.

# %%
df= df.drop_duplicates()
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# ### Missing Values/Null Values

# %%
#Missing Values/Null Values Count
missing_values =   df.isna().sum().sort_values(ascending = False)[:6]                                                  
missing_values
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# reserved_room_type        0
# assigned_room_type        0
# dtype: int64

# %%
#Non null value rows in data set
non_missing_value_in_row = df.loc[:,['company','agent','country','children']].count()
non_missing_value_in_row
# Out:
# company      5259
# agent       75203
# country     86944
# children    87392
# dtype: int64

# %%
#plt.bar(x, height, width, bottom, align)
# set plot size
plt.figure(figsize=(12,6))
#plotting bar plot
sns_plot=sns.barplot(x = missing_values.index,y =missing_values.values)
#set labels 
plt.xticks(rotation = 30)
plt.yticks(rotation = 30)
plt.title("Tob 4 null values counts")
x = missing_values.values
plt.legend(x)
                                                                                                 # Visualizing the missing values

# %%
#set plot size
plt.figure(figsize=(25, 10))
#plotting heatmap 
sns.heatmap(df.isnull(),cmap='Blues', yticklabels=False)
#set labels
plt.xlabel("Name Of Columns")
plt.title("Places of missing values in column")
# Out:
# Text(0.5, 1.0, 'Places of missing values in column')

# %% [markdown]
# ####**Insight of our data?**
# ####Dataset contains missing/null values majorly for 2 columns above 10000 rows company and agent volumns.And dataset has another 2 columns country and children below 500 rows not much effective for EDA but too get precise output need to replace the data.
# #####1.Above 3 of 4 columns are given with numarical data columns are company,agentand children. so, it can be replaced/filled with 0 at all null cells.
# #####2.And another column is country a object column can replaced/filled with "other".

# %%
# Filling/replacing null values of columns agent children and company with 0.
null_columns=['agent','children','company']
for col in null_columns:
  df[col].fillna(0,inplace=True)
  
# Replacing NA values of country column with 'others'.
df['country'].fillna('others',inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
#Successfully handled  with Null Values
df.isna().sum().sort_values(ascending=False)[:6].reset_index().rename(columns={'index':'Columns',0:'Null values'})
# Out:
#                        Columns  Null values
# 0                        hotel            0
# 1                  is_canceled            0
# 2           reservation_status            0
# 3    total_of_special_requests            0
# 4  required_car_parking_spaces            0
# 5                          adr            0

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns list
print(list(df.columns ))
# Out:
# ['hotel', 'is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_month', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr', 'required_car_parking_spaces', 'total_of_special_requests', 'reservation_status', 'reservation_status_date']

# %%
# Dataset Describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# 1. **hotel** : *Hotels(Resort Hotel or City Hotel)*
#
# 2. **is_canceled** : *Value indicating cancellation of booking, if the booking was canceled (1) or not (0)*
#
# 3. **lead_time** :* Number of days that elapsed between the entering date of the reservation booking into the PMS and the arrival date*
#
# 4. **arrival_date_year** : *Year of arrival date of guest to hotel*
#
# 5. **arrival_date_month** : *Month of arrival date of guest to hotel*
#
# 6. **arrival_date_week_number** : *Week number of year of guest arrival date*
#
# 7. **arrival_date_day_of_month** : *Day of arrival date*
#
# 8. **stays_in_weekend_nights** : *Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel*
#
# 9. **stays_in_week_nights** : *Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel*
#
# 10. **adults** : *Number of adults*
#
# 11. **children** : *Number of children*
#
# 12. **babies** : *Number of babies*
#
# 13. **meal** : *Type of meal booked. Categories are presented in standard hospitality meal packages:*
#
# 14. **country** : *Country of origin.`*
#
# 15. **market_segment** : *Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 16. **distribution_channel** : *Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 17. **is_repeated_guest** : *Value indicating if the booking name was from a repeated guest (1) or not (0)*
#
# 18. **previous_cancellations** : *Number of previous bookings that were cancelled by the customer prior to the current booking*
#
# 19. **previous_bookings_not_canceled** : *Number of previous bookings not cancelled by the customer prior to the current booking*
#
# 20. **reserved_room_type** : *Code of room type reserved. Code is presented instead of designation for anonymity reasons.*
#
# 21. **assigned_room_type** : *Code for the type of room assigned to the booking.*
#
# 22. **booking_changes** : *Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation*
#
# 23. **deposit_type** : *Indication on if the customer made a deposit to guarantee the booking.*
#
# 24. **agent** : *ID of the travel agency that made the booking*
#
# 25. **company** : *ID of the company/entity that made the booking or responsible for paying the booking.*
#
# 26. **days_in_waiting_list** : *Number of days the booking was in the waiting list before it was confirmed to the customer*
#
# 27. **customer_type** : *Type of booking, assuming one of four categories*
#
#
# 28. **adr** : *Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights*
#
# 29. **required_car_parking_spaces** : *Number of car parking spaces required by the customer*
#
# 30. **total_of_special_requests** :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# 31. **reservation_status** : *Reservation last status, assuming one of three categories*
# * Canceled – booking was canceled by the customer
# * Check-Out – customer has checked in but already departed
# * No-Show – customer did not check-in and did inform the hotel of the reason why

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for variable.
categorical_cols=list(set(df.drop(columns=['reservation_status_date','country','arrival_date_month']).columns)-set(df.describe()))
for col in categorical_cols:   
  print(f"The unique value in  column {col} are : {(df[col].unique())}  and count of unique value is {(df[col].nunique())}")
# Out:
# The unique value in  column reserved_room_type are : ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'P' 'B']  and count of unique value is 10
# The unique value in  column customer_type are : ['Transient' 'Contract' 'Transient-Party' 'Group']  and count of unique value is 4
# The unique value in  column distribution_channel are : ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']  and count of unique value is 5
# The unique value in  column hotel are : ['Resort Hotel' 'City Hotel']  and count of unique value is 2
# The unique value in  column assigned_room_type are : ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'P' 'L' 'K']  and count of unique value is 12
# The unique value in  column market_segment are : ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']  and count of unique value is 8
# The unique value in  column reservation_status are : ['Check-Out' 'Canceled' 'No-Show']  and count of unique value is 3
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# converting object type to datetime
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')
# Out:
# <ipython-input-22-b03e6e3deb7d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')

# %%
"""droppping all 166 those rows in which addtion of of adlults ,children and babies is 0. 
That simply means  no bookings were made."""
df["total_people"] = df["adults"] + df["children"]+ df["babies"]
df.drop(df[df["total_people"] == 0].index,inplace =True)
df.shape
# Out:
# <ipython-input-23-8fb3d813a0c5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["total_people"] = df["adults"] + df["children"]+ df["babies"]
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# (87230, 33)

# %%
df["Total_stay"] = df["stays_in_weekend_nights"] + df["stays_in_week_nights"]
df.columns
# Out:
# <ipython-input-24-ca1be0145a1f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Total_stay"] = df["stays_in_weekend_nights"] + df["stays_in_week_nights"]
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.Added new column as "Total_people" to existing one by cancatinating three columns adults,children and babies to check whether bookings were made are not.
#
#  *If, Total_people column is zero after concat than that column condidered as booking not happened as customers not given valid detail to proceed with with room allocation.
#
#  *So, we need to drop it total_people column with zero values.
#
# 2.And added another new column as total_stay to make handy over data visualize of stays_in_weekend_nights and stays_in_week_nights columns.
#
#  *By which we can drag info about how many total length of nights customer preferring.

# %% [markdown]
# ##**EDA(EXPLORATORY DATA ANALYSIS)**

# %% [markdown]
# ###**Univariate Variable**

# %% [markdown]
# ####**1.Which type of hotel is most prefered by the guest?**

# %%
#Counts total number of hotels
data = df["hotel"].value_counts()
data
# Out:
# City Hotel      53274
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
#setplot size
plt.figure(figsize =(12,8))
#plot pie chart
colors = ["orange","lightskyblue"]
labels = df['hotel'].value_counts().index
plt.pie(data ,explode=[0.05, 0.01],labels =labels,colors =colors, autopct='%1.2f%%', shadow=True,startangle = 10) 
#set labels, title and legend
plt.title("Most preferred type of hotel by guests")
plt.legend(labels = labels)
plt.show()

# %% [markdown]
# **Chart Selection**:Purpose for selecting this pie chart is that as our *data has less catoegories*, so we can handle *percentage precisely*.
#
# **Observation**:The insight we got from chart that most number of bookings were more for **city hotel** as compared to resort hotel that *61.1%*  and *38.9%* respectively.
#
# **Business Impact**:As most number of booking were happening for city hotels. So, we can specify that guests are willing to stay in city hotels more, so improving resort hotel in all aspects can boost positivity in reservation and helps for business growth.

# %% [markdown]
# ####**2.What is the percentage of booking cancellation?**

# %%
#Counts hotel cancellation by 0's and 1's
df["is_canceled"].value_counts()
# Out:
# 0    63221
# 1    24009
# Name: is_canceled, dtype: int64

# %%
#plot pie chart
colors = sns.color_palette("bright")[8:10]
df["is_canceled"].value_counts().plot.pie(explode = [0.03,0.02],colors = colors, autopct='%1.1f%%',shadow =True,figsize = (8,8),fontsize = 15,startangle = 10)
#set tite and lables
plt.title("Booking cancellation and non cancellation")
labels =['Not cancelled','cancelled']
plt.legend(labels = labels)

# %% [markdown]
# **Observation**:The insight we got from pie chart, that percentage of not cancelled is more as compared to cancelled that 72.5% and 27.5% respectively. where **0= not cancled** and **1= canceled**.
#
# **Business Impact**:Cancellation is more than 25% that leads to losses, and it can be improved by affordable mean prize according to other hotels in city and

# %% [markdown]
# ####**3.What is the percentage of booking changes made by the customer?**

# %%
#Counts each value of repeatation of boking changes of all the values
booking_changes_df = df["booking_changes"].value_counts().reset_index().rename(columns ={"index":"number_booking_changes","booking_changes":"counts"})[:]
booking_changes_df
# Out:
#     number_booking_changes  counts
# 0                        0   71425
# 1                        1   10868
# 2                        2    3483
# 3                        3     862
# 4                        4     347
# 5                        5     113
# 6                        6      57
# 7                        7      29
# 8                        8      14
# 9                        9       8
# 10                      10       6
# 11                      13       5
# 12                      14       3
# 13                      15       3
# 14                      17       2
# 15                      16       2
# 16                      12       1
# 17                      18       1
# 18                      11       1

# %%
#set plot size
plt.figure(figsize = (8,6))
#Group by booking_changes with its value counts
booking_changes_df = df["booking_changes"].value_counts().reset_index().rename(columns ={"index":"number_booking_changes","booking_changes":"counts"})[:11]
# color =['orange','yellow','blue','green','red','orange','yellow','blue','green','red','orange','yellow','blue','green','red','orange','yellow','blue','green']
# plt.bar(booking_changes_df["number_booking_changes"],booking_changes_df["counts"]*100 // df.shape[0],color =color,cmap ="viridis",width= 0.5)
#plotting line chart 
plt.plot(booking_changes_df["number_booking_changes"],booking_changes_df["counts"]*100//df.shape[0],marker = 's',ls = 'dashed',c='r',lw='3')     
#set title and lables
plt.title("percentage of booking changes")
plt.xlabel("number booking changes")
plt.ylabel("percentage(%) of booking changes")                                      
plt.show()

# %% [markdown]
# **Chart Selection:**Purpose for selecting this line chart that help out to show **small shifts** that may be getting hard to spot in other graphs.
#
# **Observation**:Almost **82%** of bookings were not changed by guests and followed by 1 time changes made above 10% .And highest changes made was 18 by one guest.
#
# **Business Impact**:It could be improved by making full digitalization with perfect operational efficiency of websites.

# %% [markdown]
# ####**4.In which month most of the bookings happened?**

# %%
bookings_by_months_df=df.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Creating list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
bookings_by_months_df["arrival_date_month"] = pd.Categorical(bookings_by_months_df["arrival_date_month"],categories = months,ordered = True)
#sort columns by order of months
bookings_by_months_df= bookings_by_months_df.sort_values("arrival_date_month")
bookings_by_months_df
# Out:
#    arrival_date_month  Counts
# 4             January    4685
# 3            February    6083
# 7               March    7489
# 0               April    7900
# 8                 May    8344
# 6                June    7756
# 5                July   10043
# 1              August   11242
# 11          September    6682
# 10            October    6921
# 9            November    4973
# 2            December    5112

# %%
#set plot size
plt.figure(figsize = (12,6))
#ploting line plot using seaborn
sns.lineplot(x = bookings_by_months_df["arrival_date_month"],y = bookings_by_months_df["Counts"]*100/ bookings_by_months_df["Counts"].shape[0],marker ='s', linewidth=3,alpha = 0.8,linestyle ='dashed',color='black')
# sns.barplot(x = bookings_by_months_df["arrival_date_month"],y = bookings_by_months_df["Counts"]*100/ bookings_by_months_df["Counts"].shape[0],palette="tab10", linewidth=5,alpha = 0.8,)
#Creating titles labels and xyticks
plt.title("Busiest months for hotels")
plt.xlabel("Month of guests arrival date")
plt.ylabel("Number of bookings")
plt.xticks(rotation =30)
plt.yticks(rotation =30)
# Out:
# (array([ 30000.,  40000.,  50000.,  60000.,  70000.,  80000.,  90000.,
#         100000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# **Observation**:June and August months had the rapid growth of bookings. So, summer vacation can be reason for bookings.
#
# **Business Impact**:Except summer all three winter,spring and autumn seasons don't have much bokings. So, hotels can have healthy environment of gaining more profits in summer season.

# %% [markdown]
# ####**5.What is the percentage distribution of customer type arrived to hotel?**

# %%
#To count all different customer type
df["customer_type"].value_counts()
# Out:
# Transient          71862
# Transient-Party    11692
# Contract            3135
# Group                541
# Name: customer_type, dtype: int64

# %%
#plot pie plot 
colors = sns.color_palette('bright')[8:12]
df["customer_type"].value_counts().plot.pie(explode=[0.09, 0.0,0.0,0.0],colors =colors, autopct='%1.2f%%', shadow=True, figsize=(10,10),fontsize=15) 
#setting labels  and title
plt.title("Hotel Customer type")
labels = df["customer_type"].value_counts().index                                                                                                 
plt.legend(labels = labels)

# %% [markdown]
# **Observation**:Transient customer type has more than 80% of arrivals, where as booking associated with group has lowest.
#
# **1.contract**
# >A bilateral contract between a hotel and a guest.
#
# **2.Group**
# >To  make reservations for five or more guests who have some features in common.
#
# **3.Transient**
# >Guest who is looking for short time and often ungent hotel stays.
#
# **4.Transient_Party**
# 4.when the booking is transient, but is associated to at least other transient booking
#
#
# **Business Impact**:As transient travellers has 82% market cap. so, hotels needed to have two sharing rooms more

# %% [markdown]
# ####**6.What is the percentage distribution of "deposit type"?**

# %%
#Counnt of different diposite type
df["deposit_type"].value_counts()
# Out:
# No Deposit    86085
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %%
#plot pie chart
colors = sns.color_palette("bright")
df["deposit_type"].value_counts().plot.pie(explode = [0.0,0.5,0.8],colors = colors,shadow =True,autopct = '%1.1f%%',fontsize =15,figsize =(14,8),startangle =-30)
#set labels
plt.title("percentage of Deposit type")
labels = df["deposit_type"].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels = labels)

# %% [markdown]
# **Observation**:"No deposit" guest type has more than 98% of arrivals, where as booking associated with Refundable has lowest with 0.1 percentage.
#
# **Business Impact**:Even refundable policy implemented reservations were 98% more held for no-deposit. Mean while non-refund has more percentage than refundable.so, policies need to change for arrival date vs refundable that can boost deposit type resevation.

# %% [markdown]
# ####**7.What is the percentage distribution of car parking space?.**

# %%
#counts all the parking spaces request while reservation
df["required_car_parking_spaces"].value_counts()
# Out:
# 0    79924
# 1     7273
# 2       28
# 3        3
# 8        2
# Name: required_car_parking_spaces, dtype: int64

# %%
#Group by of required car parking spaces with its value count
car_parking_spaces = df["required_car_parking_spaces"].value_counts().reset_index().rename(columns ={"index":"car_parking_spaces","required_car_parking_spaces":"counts"})
car_parking_spaces
#set plot size 
plt.figure(figsize = (8,6))
#plot scatter plot 
color= ["yellow","brown","green","red","blue"]
size = [500,400,300,200,500]
plt.scatter(x = car_parking_spaces["car_parking_spaces"],y = car_parking_spaces["counts"]*100 / df.shape[0],c=color,cmap ="viridis",alpha =1,s=size)
# plt.stem(car_parking_spaces["counts"]*100 / df.shape[0])
# (markers, stemlines, baseline) = plt.stem(car_parking_spaces["counts"]*100 / df.shape[0])
# plt.setp(markers, marker='D', markersize=10, markeredgecolor="orange", markeredgewidth=2)
#set labels and title
plt.legend(round(car_parking_spaces["counts"]*100 / df.shape[0],2))
plt.title("% of car parking spaces")
plt.xlabel("How many car parking spaces requied")
plt.ylabel("percentage(%) of car parking")
# Out:
# Text(0, 0.5, 'percentage(%) of car parking')

# %% [markdown]
# **Chart Selection:**purpose of selecting scatter plot to represent visual and statistical means to test the strength of a relationship between two variables.
#
# **Observation**:0 has the highest value with 91.6 %  that doesn't mentioned special request about car parking spaces.
#
# **0 :**No spaces required for car parking
#
# **1 :**One car parking spaces required.
#
# **Business Impact**:As most of the booking are transient customer type, so mostly parking doesn't required. Mean while group type customers may required parking spaces.

# %% [markdown]
# ####**8.Which is the most preferred meal type by the customers?**

# %%
#Counts all the meal types 
df['meal'].value_counts()
# Out:
# BB           67907
# SC            9391
# HB            9080
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
#set plot size 
plt.figure(figsize=(12,6))
#plot chart 
sns.barplot(x =df['meal'].value_counts().index,y =df['meal'].value_counts().values,palette = 'tab10')
sns.lineplot(x =df['meal'].value_counts().index,y =df['meal'].value_counts().values,marker = 's',linestyle = 'dashdot',color = 'red',linewidth = '3')
#set labels and title  
plt.xlabel('Meal Type')
plt.ylabel('Count')
plt.title("Most preferred meal type")
plt.show()

# %% [markdown]
# **Chart Selection:**In bar graph we can easily represent data and useful to compare different categorical or discrete variables.
#
# **Observation**:BB type food is most mentioned food while reservation compared to SC and HB.
#
# **BB:**Bed and breakfast.
#
# **SC:**self catering
#
# **HB:**Half Board (Breakfast and Dinner normally).
#
# **FB:**Full Board (Beakfast, Lunch and Dinner).
#
# **Undefined:**not defined food type at reservation.
#
# **Business Impact**:Food service is a dominant segment of the hotel industry that represents a significant proportion of the economy.

# %% [markdown]
# ####**9.Which is the most preferred room type by the customer?**

# %%
#Counts all the values of reserved room type  
df['reserved_room_type'].value_counts()
# Out:
# A    56436
# D    17376
# E     6036
# F     2820
# G     2050
# B      996
# C      914
# H      596
# L        6
# Name: reserved_room_type, dtype: int64

# %%
#plot figure size 
plt.figure(figsize=(12,8))
# plt.figure(fontsize=15)
#plot count plot 
sns.countplot(x =df['reserved_room_type'],order = df['reserved_room_type'].value_counts().index,palette = 'tab10')
sns.lineplot(x=df['reserved_room_type'].value_counts().index,y=df['reserved_room_type'].value_counts().values, marker ='o',linestyle = 'dotted',linewidth = '3')
#set title and labels 
plt.title("Preferred room type")
plt.xlabel("Count of room type")
plt.ylabel("Room type")
plt.show()

# %% [markdown]
# **Chart Selection:**count plot used to show the counts of observations in each categorical bin using bars.
#
#
# **Observation**:So the most preferred Room type is "A". Followed by D and E.
#
# **Business Impact**:In hotel it essential to understand the types of rooms hotel offer to its guests to enhance guest satisfaction. Customer satisfation is crucial role in Hospitality industry to enhance business.

# %% [markdown]
# ####**10.What is the percentage distribution of market segment?**

# %%
#counts the value of the market segment  
df['market_segment'].value_counts()
# Out:
# Online TA        51553
# Offline TA/TO    13855
# Direct           11780
# Groups            4922
# Corporate         4200
# Complementary      692
# Aviation           226
# Undefined            2
# Name: market_segment, dtype: int64

# %%
#set figure size 
plt.figure(figsize = (10,8))
#plot pie chart
explode = [0.0,0.0,0.0,0.1,0.2,0.4,0.6,0.9]
df['market_segment'].value_counts().plot.pie(explode = explode,autopct =' %0.1f%%',shadow = True,startangle =0,figsize = (8,11))
#set labels, title and legend
labels = df['market_segment'].value_counts().index
plt.title('% distribution of market segment')
plt.legend(bbox_to_anchor= (0.85,1),loc = 'upper left', labels = labels)

# %% [markdown]
# **Observation**:'Online TA' is mostly(59.1%) used for booking hotels. 'Offline TA/TO' and 'Direct' segment holds more than 29%.
#
# **Online TA:**Online Travel Agent
#
#
#
# **Business Impact**:Market segment helps hotel owners to understand their customers and increase total revenue by applying better pricing strategies.

# %% [markdown]
# ####**11.From which country the most number of guest are coming?**

# %%
#Group by country with its value counts and formed new variable guest_df
guest_df = df['country'].value_counts().reset_index().rename(columns = {'index':'country','country':'count_of_each_country'})[:10]
guest_df
#set figure size
plt.figure(figsize =(8,4))
#Plot scatter and line plot
color= ["red","orange","yellow","green","blue","indigo","violet","black","brown","pink"]
size = [500,400,300,200,100,500,100,100,100,100]
plt.scatter(x =guest_df['country'],y =guest_df['count_of_each_country'],c=color,cmap ="viridis",alpha =1,s=size)
sns.lineplot(x =guest_df['country'],y =guest_df['count_of_each_country'],color ='green',linestyle = 'dashdot',linewidth = '3')
#set legend, labels, titles and ticks
plt.legend(guest_df['count_of_each_country'])
plt.title('Number of guest from each country')
plt.xlabel('country names')
plt.ylabel('count of countries')
plt.xticks(rotation = 30)
plt.yticks(rotation = 730)
plt.title('Top 10 countries, where the Hotels receiving Guests')
plt.show()

# %%
#importing the folium library
import folium
import plotly.express as px

# %%
#Group by of country with its value counts formed new variable guest
guest = df['country'].value_counts().reset_index().rename(columns = {'index':'country','country':'count_of_each_country'})
guest
# Out:
#     country  count_of_each_country
# 0       PRT                  27355
# 1       GBR                  10424
# 2       FRA                   8823
# 3       ESP                   7244
# 4       DEU                   5385
# ..      ...                    ...
# 173     MMR                      1
# 174     BFA                      1
# 175     CYM                      1
# 176     MLI                      1
# 177     KHM                      1
#
# [178 rows x 2 columns]

# %%
 #creating actual base map 
 actual_base_map = folium.Map()

# %%
#plotting chloropleth map to show the location of the country 
guest_from_each_country = px.choropleth(guest,locations =guest['country'],color =guest['count_of_each_country'])
guest_from_each_country.update_layout(width = 1200,height =700)
guest_from_each_country.show('jpg')

# %% [markdown]
# **Chart Selection:**Chloropleth map provide an easy way to visualize how a variable varies across a geographic area.
#
# **Observation**: Most of the guests are coming from portugal, that is more than 27000 guests are from portugal. Followed by United kingdom and France.
#
#
# abbreevations for countries-
#
#
#
# 1.   PRT- Portugal
# 2.   GBR- United Kingdom
# 3.   FRA- France
# 4.   ESP- Spain
# 5.   DEU - Germany
# 6.   ITA -Itlay
# 7.   IRL - Ireland
# 8.   BEL -Belgium
# 9.   BRA -Brazil
# 10.  NLD-Netherlands

# %% [markdown]
# ###**Bivariate and Miltivariate**

# %% [markdown]
# ####**1.what is booking cancellation year wise**

# %%
#separating the value (1) of the is_canceled column
df1 = df[df['is_canceled']==1]
#Group by of arrival_date_year and taking count of is_canceled
prem =df.groupby('arrival_date_year')['is_canceled'].count()
prem
# Out:
# arrival_date_year
# 2015    13284
# 2016    42313
# 2017    31633
# Name: is_canceled, dtype: int64

# %%
#plot count plot 
sns.countplot(data = df,x="arrival_date_year",hue = "is_canceled",palette = 'tab10')
#set labels and titles
plt.xlabel('Arrival data year')
plt.title('Year wise booking cancellation--> 1 is cancelled')
# Out:
# Text(0.5, 1.0, 'Year wise booking cancellation--> 1 is cancelled')

# %% [markdown]
# **Observation**:In 2016 the  cancellation of booking was more than 10000 later next year 2017 down fall to margin of 10000.
#
# **Business Impact**:Raise of graph year wise of cancellation could memorize us as hotel runs under inappropriate environment. Down fall could helps us over productivity.

# %% [markdown]
# ####**2.Which year had highest booking hotel wise?**

# %%
#plot count plot for arrival_date_year with hue hotel
sns.countplot(data = df,x="arrival_date_year",hue = "hotel",palette ='tab10')
#set title
plt.title("Highest booking hotel wise")
# Out:
# Text(0.5, 1.0, 'Highest booking hotel wise')

# %% [markdown]
# **Observation**:Except 2015 other two years city hotel has more booking as compared to resort hotel.In 2016 has more bookings for both hotels as compared to 2015 ands 2017.
#
# **Business Impact**:Every year is very crucial for hotels as that need to improve year by year by  rectifying post negative to improve reservation counts.

# %% [markdown]
# ####**3.Which hotel has highest ADR**

# %%
#Group by of hotel with mean of adr 
grp_by_hotel =df.groupby('hotel')['adr'].mean().reset_index()
grp_by_hotel
#set figure size 
plt.figure(figsize=(10,8))
#plotting chart of bar plot 
sns.barplot(x=grp_by_hotel['hotel'],y=grp_by_hotel['adr'],palette ='bright')
#set legend and title 
plt.legend(round(grp_by_hotel['adr'],2))
plt.title("Avarage Daily Rate for each hotel")
# Out:
# Text(0.5, 1.0, 'Avarage Daily Rate for each hotel')

# %% [markdown]
# **Observation**:City hotel has higher Average Daily Rate of 111.27 as compared to resort hotel.
#
# **Business Impact**:Productivity in business can be seen by ADR.More Revenue of the hotels proposional to the more Adr.

# %% [markdown]
# ####**4.Which hotel type has the highest lead time?**

# %%
#Group by hotel with mean as lead_time
lead_time = df.groupby('hotel')['lead_time'].mean().reset_index()
lead_time
#set figure size 
plt.figure(figsize=(6,6))
#plotting chart of barplot
sns.barplot(x =lead_time['hotel'],y = lead_time['lead_time'], palette='bright')
#set title
plt.title("Lead time hotel wise")
# plt.legend(round(lead_time['lead_time'],2))
# Out:
# Text(0.5, 1.0, 'Lead time hotel wise')

# %% [markdown]
# **Chart Selection:**In bar graph we can easily represent data and useful to compare different categorical or discrete variables.
#
# **Observation**:Resort hotels has slightly  high avg lead time.
#
# **Business Impact**:That means customers plan their trips very early.But it could be a chance of cancellation as time goes on cause due to better price hotels and plan changes etc..,For this datset we need check with heatmap chart whether lead time helps or not.

# %% [markdown]
# ####**5.Which hotel has highest waiting time?**

# %%
#Group by hotel with mean as days_in_waiting_list
waiting_time = df.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
waiting_time
#plotting chart of barplot
sns.barplot(x =waiting_time['hotel'],y = waiting_time['days_in_waiting_list'],palette = 'bright')
#set title
plt.title("Avg of waiting list")
# Out:
# Text(0.5, 1.0, 'Avg of waiting list')

# %% [markdown]
# **Observation**:City hotel has highest in average of waiting list of days more than 1 day compared to resort hotel.
#
# **Business Impact**:Waiting list of reservation could lead to cancellation.As more days of waiting could be the heighest chances of cancellation.

# %% [markdown]
# ####**6.Which hotel has most repeated guests?**

# %%
#separating the repeated guests value (1) df to new repeated_guestdata frame
repeated_guest = df[df['is_repeated_guest']==1]
#Group by hotel by its size count
hotel_repeated_guest=repeated_guest.groupby('hotel').size().reset_index().rename(columns={0:'count_of_repeated_guests'})
hotel_repeated_guest
# Out:
#           hotel  count_of_repeated_guests
# 0    City Hotel                      1657
# 1  Resort Hotel                      1707

# %%
#set figure of the plot
plt.figure(figsize = (12,14))
#plotting chart of bar plot 
sns.barplot(x =hotel_repeated_guest['hotel'],y=hotel_repeated_guest['count_of_repeated_guests'])
#set title and legend 
plt.legend(round(hotel_repeated_guest['count_of_repeated_guests'],2))
plt.title("Repeated guests hotel wise")
# Out:
# Text(0.5, 1.0, 'Repeated guests hotel wise')

# %% [markdown]
# **Observation**:Resort hotel has slightly more repeated guests of 1707 as compared to city hotel.And difference of 50 repeated guests.
#
# **Business Impact**:Repeating of the guests can be increased by Prioritizing the guest experience.

# %% [markdown]
# #####**7.Which market segment has highest cancellation rate?**

# %%
#separating cancelled value(1) to new msegment_cancellation
msegment_cancellation = df[df['is_canceled']==1]
#Group by market_segment and hotel with its size
msegment_cancellation=msegment_cancellation.groupby(['market_segment','hotel']).size().reset_index().rename(columns={0:'count_of_market_segment'})
msegment_cancellation
# Out:
#    market_segment         hotel  count_of_market_segment
# 0        Aviation    City Hotel                       45
# 1   Complementary    City Hotel                       54
# 2   Complementary  Resort Hotel                       31
# 3       Corporate    City Hotel                      263
# 4       Corporate  Resort Hotel                      246
# 5          Direct    City Hotel                      912
# 6          Direct  Resort Hotel                      825
# 7          Groups    City Hotel                      887
# 8          Groups  Resort Hotel                      445
# 9   Offline TA/TO    City Hotel                     1257
# 10  Offline TA/TO  Resort Hotel                      800
# 11      Online TA    City Hotel                    12615
# 12      Online TA  Resort Hotel                     5627
# 13      Undefined    City Hotel                        2

# %%
#set figure plot 
plt.figure(figsize = (8,5))
#plotting chart of barplot 
sns.barplot(x='market_segment',y='count_of_market_segment',hue = 'hotel',data=msegment_cancellation)
#set title and ticks 
plt.xticks(rotation = 30)
plt.yticks(rotation = 15)
plt.title("cancellation rate vs market segment wise")
# Out:
# Text(0.5, 1.0, 'cancellation rate vs market segment wise')

# %% [markdown]
# **Observation**:Online TA/TO market segment has the highest booking cancellation in both the hotel types, city hotel with more than 12000 and resort hotel with more than 5000.
#
# **Business Impact**:cancellation from particular market segment could be becouse of strategies doesn't match like other segment or could be more because more reservation, so, cancellation is directly proportional to more reservation.

# %% [markdown]
# ####**8.Which distribution channel has highest cancellation rate?**

# %%
##separating cancelled value(1) to new distribution_cancellation
distribution_cancellation = df[df['is_canceled']==1]
#Group by distribution_channel and hotel with its size
distribution_cancellation=distribution_cancellation.groupby(['distribution_channel','hotel']).size().reset_index().rename(columns={0:'count_of_distribution_channel'})
distribution_cancellation
# Out:
#   distribution_channel         hotel  count_of_distribution_channel
# 0            Corporate    City Hotel                            330
# 1            Corporate  Resort Hotel                            316
# 2               Direct    City Hotel                            971
# 3               Direct  Resort Hotel                            952
# 4                  GDS    City Hotel                             36
# 5                TA/TO    City Hotel                          14694
# 6                TA/TO  Resort Hotel                           6706
# 7            Undefined    City Hotel                              4

# %%
#set figure size
plt.figure(figsize = (8,5))
#plotting chart of bar plot
sns.barplot(x='distribution_channel',y='count_of_distribution_channel',hue = 'hotel',data=distribution_cancellation)
#set title and ticks
plt.xticks(rotation = 30)
plt.yticks(rotation = 15)
plt.title('cancellation rate vs distribution channel wise')
# Out:
# Text(0.5, 1.0, 'cancellation rate vs distribution channel wise')

# %% [markdown]
# **Observation**:TA/TO distribution channel has the highest booking cancellation in both the hotel types, city hotel with more than 14000 and resort hotel with more than 6000.
#
# **Business Impact**:cancellation from particular distributional channel could be because of strategies doesn't match like other market segment or could be more because more reservation at perticular channel.

# %% [markdown]
# ####**9.Which distribution channels creates more ADR for business?**

# %%
#separating cancelled value(0) to new distribution_cancellation
data = df[df['is_canceled']==0]
#Group by distribution_channel and hotel with mean of adr.
dc_adr_df = data.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
dc_adr_df
# Out:
#   distribution_channel         hotel         adr
# 0            Corporate    City Hotel   82.857996
# 1            Corporate  Resort Hotel   51.020394
# 2               Direct    City Hotel  111.646008
# 3               Direct  Resort Hotel  104.427551
# 4                  GDS    City Hotel  119.725310
# 5                TA/TO    City Hotel  110.034562
# 6                TA/TO  Resort Hotel   94.259845
# 7            Undefined  Resort Hotel  112.700000

# %%
#set plot size 
plt.figure(figsize=(8,6))
#plotting chart of barplot
sns.barplot(x =dc_adr_df['distribution_channel'],y=dc_adr_df['adr'],hue = dc_adr_df['hotel'])
#set title
plt.title("ADR across distribution channel")
# Out:
# Text(0.5, 1.0, 'ADR across distribution channel')

# %% [markdown]
# **Observation**:Global distribution system(GDS) channel has the highest adr for city hotel.for resort hotel GDS need to start reservation service.And at some undefined channel need to focus on city hotel reservation too.
#
# **Business Impact**:The goal of most hotel distribution channels strategies is to increase visibility with our ideal guests, thereby increasing bookings.

# %% [markdown]
# ####**10.Which market segment creats more ADR for business?**

# %%
#Group by 'arrival_date_month','market_segment' and 'hotel','is_canceled' with mean of adr.
data_adr = df.groupby(['arrival_date_month','market_segment','hotel','is_canceled'])['adr'].mean().reset_index()
data_adr
# Out:
#     arrival_date_month market_segment         hotel  is_canceled         adr
# 0                April       Aviation    City Hotel            0  100.848485
# 1                April       Aviation    City Hotel            1  104.083333
# 2                April  Complementary    City Hotel            0    0.346154
# 3                April  Complementary    City Hotel            1    0.000000
# 4                April  Complementary  Resort Hotel            0    1.566667
# ..                 ...            ...           ...          ...         ...
# 304          September  Offline TA/TO  Resort Hotel            1   71.163021
# 305          September      Online TA    City Hotel            0  129.094224
# 306          September      Online TA    City Hotel            1  135.926044
# 307          September      Online TA  Resort Hotel            0  117.233572
# 308          September      Online TA  Resort Hotel            1  119.066839
#
# [309 rows x 5 columns]

# %%
#set plot size 
plt.figure(figsize = (8,6))
#plotting chart of barplot
sns.barplot(x ='market_segment',y='adr',hue = 'hotel',data = data_adr.sort_values(by='adr',ascending=False))
#set title and ticks
plt.title("ADR across market segment")
# plt.xticks(rotation = 0)
plt.yticks(rotation = 30)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120., 140.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# **Observation:**'Direct' and 'Online TA' are contributing the most in both types of hotels.
#
# **TA** is Travel agent
#
# **TO** is Tour Operator
#
# **Business impact:**
# Aviation segment should focus on increasing the bookings of 'City Hotel'

# %% [markdown]
# ####**11.How ADR is relating with total stay**

# %%
#creating new data frame adr_stay through groupby 'Total_stay','adr' and "hotel" with aggregate count 
adr_stay = df.groupby(['Total_stay','adr',"hotel"]).agg('count').reset_index()
adr_stay =adr_stay.iloc[:,:3]
adr_stay=adr_stay[:18000]
adr_stay
# Out:
#        Total_stay     adr         hotel
# 0               0    0.00    City Hotel
# 1               0    0.00  Resort Hotel
# 2               1    0.00    City Hotel
# 3               1    0.00  Resort Hotel
# 4               1    1.00    City Hotel
# ...           ...     ...           ...
# 17995           7  212.06    City Hotel
# 17996           7  212.10  Resort Hotel
# 17997           7  212.14  Resort Hotel
# 17998           7  212.29    City Hotel
# 17999           7  212.29  Resort Hotel
#
# [18000 rows x 3 columns]

# %%
#plotting chart lineplot
sns.lineplot(x=adr_stay['Total_stay'],y =adr_stay['adr'],ls='dashdot',lw ='3')
#set title
plt.title("Total stay with ADR")
# Out:
# Text(0.5, 1.0, 'Total stay with ADR')

# %% [markdown]
# **Chart Selection:**Purpose for selecting this line chart that help out to show **small shifts** that may be getting hard to spot in other graphs.
#
# **Observation**:ADR has approximately same to total stay till 6 stays.
#
# **Business Impact**:As the total stay increases the  adr also increases slightly.

# %%
#Droping adr value above 5000 as i is outlier
df.drop(df[df['adr'] > 5000].index, inplace = True)
#set figure size
plt.figure(figsize=(16,8))
#plotting chart of scatter plot
sns.scatterplot(x=df['Total_stay'],y=df['adr'])
#set title
plt.title('Relationship between  adr and total stay')
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Text(0.5, 1.0, 'Relationship between  adr and total stay')

# %% [markdown]
# **Chart Selection:**purpose of selecting scatter plot to represent visual and statistical means to test the strength of a relationship between two variables.
#
# **Observation:**From graph it shows that fluctuations after long stays of 6 days.
#
# **Busines impact:** From above scatter we can say that as the stay increases adr is decreasing. Thus for longer stays customer can get good adr

# %% [markdown]
# ####**12.What is the length of total stay hotel wise?**

# %%
#Group by of Total_stay and hotel with aggregation count
hotel_stay = df.groupby(['Total_stay',"hotel"]).agg('count').reset_index()
hotel_stay =hotel_stay.iloc[:,:3]
# hotel_stay=hotel_stay[:18000]
hotel_stay=hotel_stay.rename(columns =({'is_canceled':'count_of_stay'}))
#set figure size
plt.figure(figsize = (15,8))
#plotting chart for barplot
sns.barplot(x=hotel_stay['Total_stay'],y=hotel_stay['count_of_stay'],hue = 'hotel',data =hotel_stay)
#set title
plt.title('Optimal stay length of both hotel types')
# Out:
# Text(0.5, 1.0, 'Optimal stay length of both hotel types')

# %% [markdown]
# **Observation**:Total stay raised for three days than we can see down fall gradually.Three days stays has highest mark above 13000 for city hotel.
#
# **Business impact:**As the optimal stay length increases after 7 days, than stay of guests decreases.

# %% [markdown]
# ####**13.Does guest alloted same room type which reserved by them?**

# %%
#creating function same_room_allotment to check different room allocated
def same_room_allotment(x):
  #checks variable reserved_room_type and assigned_room_type.
  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1    #returns one if condition is true
  else:
    return 0     #returns 0 if the condition is false

# %%
##Creating a new variable by calling function
df['Same_room_alloted_or_not']=df.apply(lambda x: same_room_allotment(x),axis=1)
df['Same_room_alloted_or_not']
# #groupby is canceled
grp_by_canceled_df=df.groupby('is_canceled')
grp_by_canceled_df
# create DF and calculate  percentage of same room alloted  or not
DF=pd.DataFrame(grp_by_canceled_df['Same_room_alloted_or_not'].sum()*100/grp_by_canceled_df.size()).rename(columns={0:"percentage"})
DF

#set plot size and plot barchart
plt.figure(figsize=(12,8))
sns.barplot(x=DF.index,y=DF['percentage'],palette = 'tab10')

# set labels
plt.title('%  of not getting the same room vs Booking cancellation')
plt.xlabel('is_canceled')
plt.ylabel('% of not getting same room as per reservation')
plt.xticks([0,1],['Not canceled','canceled'])
# Out:
# <ipython-input-71-2e1490cc2b44>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ([<matplotlib.axis.XTick at 0x7f84523fc700>,
# ...
#  [Text(0, 0, 'Not canceled'), Text(1, 0, 'canceled')])

# %% [markdown]
# **Observation:**Booking cancelled percentage is (2.5%) and not cancelled is more than (19%)
#
# **Business impact:**No much effect on cancellation of the bookings even if the guests are not assigned with rooms which they reserved during booking but with 2.5%.

# %% [markdown]
# ####***ADR across each month**

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'total_people',
#        'Total_stay', 'Same_room_alloted_or_not'],
#       dtype='object')

# %%
#Group by 'arrival_date_month','market_segment','hotel' and 'is_canceled' with mean adr
data_adr = df.groupby(['arrival_date_month','market_segment','hotel','is_canceled'])['adr'].mean().reset_index()
data_adr
#Created list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
data_adr["arrival_date_month"] = pd.Categorical(data_adr["arrival_date_month"],categories = months,ordered = True)
#sorting months name from january to December
data_adr= data_adr.sort_values("arrival_date_month")
data_adr
#set figure size
plt.figure(figsize=(20,8))
#plotting chart of lineplot
sns.lineplot(x=data_adr['arrival_date_month'],y=data_adr['adr'],hue=data_adr['hotel'])

# set lables
plt.title('ADR across each month')
plt.xlabel('Month')
plt.ylabel('ADR')
# Out:
# Text(0, 0.5, 'ADR')

# %% [markdown]
# **Observation:**For Resort hotel is ADR is high in the months June,July,August as compared to City Hotels.City hotel has avg ADR difference is 40 range for every months.
#
# **Business impact:**Customers/People wants to spend their Summer vaccation in Resorts Hotels.The best time for guests to visit Resort is January, February, March, April,October, November and December as the avrage daily rate in this month is very low

# %% [markdown]
# ####***ADR relation with total number of people**

# %%
#set plot size
plt.figure(figsize=(20,8))
#Considering totel people less than 6 to look better in boxplot 
df1=df[df['total_people'] < 6]
df2=df1[df1['adr'] < 1000]
#plotting boxplot
sns.boxplot(x=df2['total_people'],y=df2['adr'])
#set title
plt.title('ADR v/s Total Number of people')
# Out:
# Text(0.5, 1.0, 'ADR v/s Total Number of people')

# %% [markdown]
# **Chart Selection:**A box plot is a highly visually effective way of viewing a clear summary of one or more sets of data.
#
# **Observation:**As chart shows that total number of people increases  adr also increases.
#
# **Business impact:**Adr and total people are directly proportional to each other.Mean while outlier of adr is more for some total_people values. so, property management system need to rectify such errors.

# %% [markdown]
# ####**Correlation of dataset columns**

# %%
#set plot size
plt.figure(figsize=(15,12))
#Plotting chart of heat map 
sns.heatmap(df.corr(),annot = True)
#setting title
plt.title('Co-relation of the columns')
# Out:
# Text(0.5, 1.0, 'Co-relation of the columns')

# %% [markdown]
# **Chart Selection:**heat map is a representation of data in the form of a map or diagram in which data values are represented as colours.
#
# **Observation:**
# >lead_time and total_stay is positively correlated.That means more in the total stay of customer will relate more in lead time.
#
# >adults,childrens and babies are positive corelated to adr. That means more the people more will be adr.
#
# >is_repeated guest and previous bookings not canceled has strong correlation. may be repeated guests are not more likely to cancel their bookings.
#
# >is_canceled and same_room_alloted_or_not are negatively correlated. That means  customer is unlikely to cancel his bookings if he don't get the same room as per reserved room. We have visualized it above.

# %% [markdown]
# ####**pair plot**

# %%
#paring the columns with huename of variable in data 'hotel' to show the trends with columns 'agent','adr','arrival_date_week_number' and 'lead_time'.
data = df.loc[:,['agent','adr','arrival_date_week_number','lead_time','hotel']].reset_index()
data_new=data.loc[:,['agent','adr','arrival_date_week_number','lead_time','hotel']]

# %%
# plotting the pair plot
sns.pairplot(data_new, hue="hotel")

# %% [markdown]
# **Chart Selection:** This creates a nice visualisation and helps us understand and allows us to plot pairwise relationships between variables within a dataset, by summarising a large amount of data in a single figure.
#
# **Observation:**Diagonal chart of pair plot are univariate variable,and rest of 12 chart are bivariate variable.
#
# >City hotel shows trend in all the univariate variable compared to resort hotel,
# which shows chart across diagonal of pair plot.
#
# >Other than diaginal chart,12 charts are bivariate shows trends between two variables like Agent,adr,arrival date week number and lead time.
#
# >Agent and lead time shows resort hotel has greater lead time than city hotel.
#
# >lead time and adr shows adr higher for resort hotel.
#
# >Arrival date week number and lead time shows highest lead time records by Resort hotel.

# %% [markdown]
# ## **Solution to Business Objective**

# %% [markdown]
# Both the Hotels are performing at their best level to improve the ADR.But,
#
# >offering their guests the highest levels of luxury through personalized services will helps in generating repeated guests.
#
# >Assigning the same room type as reserved could help in decreasing the cancellation.
#
# >Offering the special discounts on non holidays periods by applying strategies.
#
# >Market segment and distributional channel should focus on improvement over booking by applying individual strategies.
#
# >PMS property management system need to rectify post technical glitches as guests should not face issues while bookings.
#
# >Providing delicious food and minimising the waiting list time helps out for business development.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# >City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
#
# >27.5 % bookings were got cancelled out of all the bookings.
#
# >The percentage of 0 changes made in the booking was more than 82 %. Percentage of Single changes made was about 10%.
#
# >Most of the customers (91.6%) do not require car parking spaces.
#
# >79.1 % bookings were made through TA/TO (travel agents/Tour operators).
#
# >BB( Bed & Breakfast) is the most preferred type of meal by the guests.
#
# >Maximum number of guests were from Portugal, i.e. more than 25000 guests.
#
# >Most of the bookings for City hotels and Resort hotel were happened in 2016.
#
# >Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
#
# >Booking cancellation rate is high for City hotels which almost 30 %.
# Average lead time for resort hotel is high.
#
# >Waiting time period for City hotel is high as compared to resort hotels. That means city hotels are much busier than Resort hotels.
#
# >Resort hotels have the most repeated guests.
#
# >Optimal stay in both the type hotel is less than 7 days. Usually people stay for a week.
#
# >Almost 19 % people did not cancel their bookings even after not getting the same room which they reserved while booking hotel. Only 2.5 % people cancelled the booking.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
